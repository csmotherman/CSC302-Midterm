# %% [markdown]
# <a href="https://colab.research.google.com/github/csmotherman/CSC302-Midterm/blob/main/Possible_Visual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('/content/drive/MyDrive/Sleep_health_and_lifestyle_dataset.csv')
sns.set_theme(style="darkgrid")

sns.displot(
    df, x="Age", col="Sleep Disorder", row="Gender",
    binwidth=5, height=6, facet_kws=dict(margin_titles=True),
)
